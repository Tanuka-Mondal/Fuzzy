# %% [markdown]
# <a href="https://colab.research.google.com/github/Tanuka-Mondal/Fuzzy/blob/main/fuzzy3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U scikit-fuzzy
# Out:
# ...
#      |████████████████████████████████| 993 kB 5.2 MB/s
# ...
#   Created wheel for scikit-fuzzy: filename=scikit_fuzzy-0.4.2-py3-none-any.whl size=894089 sha256=19792e4466fb65241962de999d2d8fb5c73954f5545a4cce8250a449272102d6
#   Stored in directory: /root/.cache/pip/wheels/d5/74/fc/38588a3d2e3f34f74588e6daa3aa5b0a322bd6f9420a707131
# Successfully built scikit-fuzzy
# ...

# %%
import numpy as np
import skfuzzy as fuzzy
from skfuzzy import control as ctrl

# %%
import matplotlib.pyplot as plt

# %%
bi = ctrl.Antecedent(np.arange(0,101,1),'Battery percentage')
bi['very low'] = fuzzy.gaussmf(bi.universe,0,15)
bi['low'] = fuzzy.gaussmf(bi.universe,25,15)
bi['medium'] = fuzzy.gaussmf(bi.universe,45,15)
bi['high'] = fuzzy.gaussmf(bi.universe,65,15)
bi['very high'] = fuzzy.gaussmf(bi.universe,100,15)
bi.view()

# %%
bi = ctrl.Antecedent(np.arange(0,101,1),'Battery percentage')
bi['very low'] = fuzzy.gbellmf(bi.universe,10,8,0)
bi['low'] = fuzzy.gbellmf(bi.universe,10,8,25)
bi['medium'] = fuzzy.gbellmf(bi.universe,10,8,50)
bi['high'] = fuzzy.gbellmf(bi.universe,10,8,75)
bi['very high'] = fuzzy.gbellmf(bi.universe,10,8,100)
bi.view()
